# %%
import pandas as pd
import numpy as np


data = {
    'Employee_ID': [101, 102, 103, 104, 101, 105, 106, 107],
    'Age': [25, 30, np.nan, 45, 25, 35, 200, 28],  # มี missing และ outlier (อายุ 200)
    'Salary': [50000, 60000, 55000, np.nan, 50000, 65000, 40000, 48000], # มี missing
    'Department': ['IT', 'HR', 'IT', 'Marketing', 'IT', 'HR', 'IT', 'Marketing'],
    'Left_Company': ['No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes'] # Target Class
}
df = pd.DataFrame(data)


print("--- Data Shape ---")
print(df.shape) 
print("\n")


print("--- Data Types ---")
print(df.dtypes)
print("\n")


print("--- Summary Statistics ---")
print(df.describe(include='all')) 
print("\n")


print("--- Missing Values ---")
print(df.isnull().sum())
print("\n")


print("--- Duplicate Records ---")
print(f"Total duplicate rows: {df.duplicated().sum()}")
print("\n")


print("--- Class Distribution (Left_Company) ---")
print(df['Left_Company'].value_counts())
# Out:
# --- Data Shape ---
# (8, 5)
#
#
# --- Data Types ---
# Employee_ID       int64
# Age             float64
# Salary          float64
# Department          str
# Left_Company        str
# dtype: object
#
#
# --- Summary Statistics ---
#         Employee_ID         Age        Salary Department Left_Company
# count      8.000000    7.000000      7.000000          8            8
# unique          NaN         NaN           NaN          3            2
# top             NaN         NaN           NaN         IT           No
# freq            NaN         NaN           NaN          4            5
# mean     103.625000   55.428571  52571.428571        NaN          NaN
# std        2.263846   64.132304   8243.323417        NaN          NaN
# min      101.000000   25.000000  40000.000000        NaN          NaN
# 25%      101.750000   26.500000  49000.000000        NaN          NaN
# 50%      103.500000   30.000000  50000.000000        NaN          NaN
# ...

# %%
# !pip install pandas numpy seaborn matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.9 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.9 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.9 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.9 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.9 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/9.9 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 2.0 MB/s eta 0:00:03
# ...
